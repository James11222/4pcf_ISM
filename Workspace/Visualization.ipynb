# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

import ipywidgets as widgets
from ipywidgets import HBox, VBox
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

import mpl_toolkits.axes_grid1 as axgrid
from mpl_toolkits.axes_grid1 import make_axes_locatable
#Need this line for widgets to work
# %matplotlib inline
# %matplotlib notebook
#plt.style.use('dark_background')
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['font.size'] = 14
# Out:
# In /Users/jamessunseri/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/jamessunseri/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/jamessunseri/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /Users/jamessunseri/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %% [markdown]
# # Load in $\zeta_{\ell_1, \ell_2, \ell_3}^{b_1, b_2,b_3}$

# %%
#Load in data from 4pcf calculation
zeta = np.load('4pcf_coefficients_normed_GRF.npy')

print(np.shape(zeta))

#Load in data from 4pcf calculation
zeta_2 = np.load('4pcf_coefficients_normed_GRF_doubled.npy')

print(np.shape(zeta_2))
# Out:
# (6, 6, 6, 4, 4, 4)
# (6, 6, 6, 4, 4, 4)

# %% [markdown]
# # Build Widgets and Index Dictionary

# %%
ell_max=5
index_dict = {}

for l_1 in range(0,ell_max+1, 1):
    for l_2 in range(0,ell_max+1, 1):
        for l_3 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1):
            if l_3 >= np.abs(l_1 - l_2) and l_3 < (min(l_1 + l_2, ell_max) + 1): 
                index_dict[str(l_1) + str(l_2) + str(l_3)] = ("$\\ell_1, \ell_2, \ell_3$ = " + str(l_1) + ',' +
                                                    str(l_2) + ',' + str(l_3))
            else:
                index_dict[str(l_1) + str(l_2) + str(l_3)] = "Invalid Combination"

# %%
from IPython.core.display import HTML
nbins = np.shape(zeta)[-1]
ell_max=5

slider1 = widgets.IntSlider(
                            value=0,
                            min=0,
                            max=ell_max,
                            step=1,
                            description=r'\(\ell_1\)')

slider2 = widgets.IntSlider(
                            value=0,
                            min=0,
                            max=ell_max,
                            step=1,
                            description=r'\(\ell_2\)')

slider3 = widgets.IntSlider(
                            value=0,
                            min=0,
                            max=ell_max,
                            step=1,
                            description=r'\(\ell_3\)')

slider4 = widgets.IntSlider(
                            value=0,
                            min=0,
                            max=nbins-1,
                            step=1,
                            description=r'\(b_1\)')

slider5 = widgets.IntSlider(
                            value=0,
                            min=0,
                            max=nbins-1,
                            step=1,
                            description=r'\(b_2\)')

slider6 = widgets.IntSlider(
                            value=0,
                            min=0,
                            max=nbins-1,
                            step=1,
                            description=r'\(b_3\)')

# %% [markdown]
# # Create Visualization Plot for 4PCF

# %%
def make_plot(l_1=0, l_2=0, l_3=0, b_1=0, b_2=0, b_3=0):
    
    xylabel_fontsize = 22
    sub_title_fontsize = 22
    sup_title_fontsize = 30
    text_fontsize = 18
    f = plt.figure(figsize=(10,8))
    
#     f, (ax2) = plt.subplots(1,1, figsize=(8,8))
    f.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$', fontsize=sup_title_fontsize)
    
#     ax1.cla()
#     ax1.imshow(zeta[l_1,l_2,l_3,b_1,:,:].real, origin='lower')
#     ax1.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
#     ax1.set_title('$b_1$ = ' + str(b_1), fontsize=sub_title_fontsize)
#     ax1.set_xticks(range(nbins))
#     ax1.set_yticks(range(nbins))
#     ax1.set_xlabel("$b_2$",fontsize=xylabel_fontsize)
#     ax1.set_ylabel("$b_3$", fontsize=xylabel_fontsize)
    
#     ax2.cla()
#     ax2.imshow(zeta[l_1,l_2,l_3,:,b_2,:].real, origin='lower')
#     ax2.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
#     ax2.set_title('$b_2$ = ' + str(b_2), fontsize=sub_title_fontsize)
#     ax2.set_xticks(range(nbins))
#     ax2.set_yticks(range(nbins))
#     ax2.set_xlabel("$b_1$",fontsize=xylabel_fontsize)
#     ax2.set_ylabel("$b_3$", fontsize=xylabel_fontsize)
#     plt.colorbar()
    
    plt.cla()
    plt.imshow(zeta[l_1,l_2,l_3,:,b_2,:].real, origin='lower')
    plt.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
    plt.title('$b_2$ = ' + str(b_2), fontsize=sub_title_fontsize)
    plt.xticks(range(nbins))
    plt.yticks(range(nbins))
    plt.xlabel("$b_1$",fontsize=xylabel_fontsize)
    plt.ylabel("$b_3$", fontsize=xylabel_fontsize)
    plt.colorbar()
    
#     ax3.cla()
#     ax3.imshow(zeta[l_1,l_2,l_3,:,:,b_3].real, origin='lower')
#     ax3.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
#     ax3.set_title('$b_3$ = ' + str(b_3), fontsize=sub_title_fontsize)
#     ax3.set_xticks(range(nbins))
#     ax3.set_yticks(range(nbins))
#     ax3.set_xlabel("$b_1$",fontsize=xylabel_fontsize)
#     ax3.set_ylabel("$b_2$", fontsize=xylabel_fontsize)
    
    f.tight_layout()



out = widgets.interactive_output(make_plot, {'l_1':slider1,
                                     'l_2':slider2, 'l_3':slider3, 'b_1':slider4,
                                            'b_2':slider5, 'b_3':slider6,})

# we can add vertical and horizontal boxes for styling!
box1 = widgets.VBox([slider1])
ui1 = widgets.HBox([box1])

box2 = widgets.VBox([slider2,slider5])
ui2 = widgets.HBox([box2])

box3 = widgets.VBox([slider3])
ui3 = widgets.HBox([box3])

ui = widgets.HBox([ui1, ui2, ui3])



display(ui,out)
# Out:
# ...
# Output()

# %% [markdown]
# # Scaling Test

# %%
# We need to calculate the ration between the unscaled and scaled 4PCF coefficients

#Load in data from 4pcf calculation
zeta = np.load('4pcf_coefficients_normed_GRF_unscaled.npy')

print(np.shape(zeta))

#Load in data from 4pcf calculation
zeta_2 = np.load('4pcf_coefficients_normed_GRF_scaled.npy')

print(np.shape(zeta_2))


ratio = (zeta_2)/(zeta + 1e-10)
# Out:
# (6, 6, 6, 4, 4, 4)
# (6, 6, 6, 4, 4, 4)

# %%
ell_max=5
nbins = np.shape(zeta_2)[-1]

def make_plot(l_1=0, l_2=0, l_3=0, b_1=0, b_2=0, b_3=0):
    
    xylabel_fontsize = 22
    sub_title_fontsize = 22
    sup_title_fontsize = 30
    text_fontsize = 18
    upper_bound = 5e-10
    lower_bound = -1e-10
    colorbar_ax_percent = '5%'
    #f = plt.figure(figsize=(10,8))
    
    f, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(28,9))
    #f.clf()
    f.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$', fontsize=sup_title_fontsize)
    
    
    ax1.cla()
    im1 = ax1.imshow(zeta[l_1,l_2,l_3,:,b_2,:].real, origin='lower')
    ax1.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
    ax1.set_title('$b_2$ = ' + str(b_2), fontsize=sub_title_fontsize)
    ax1.set_xticks(range(nbins))
    ax1.set_yticks(range(nbins))
    ax1.set_xlabel("$b_1$",fontsize=xylabel_fontsize)
    ax1.set_ylabel("$b_3$", fontsize=xylabel_fontsize)
    divider1 = axgrid.make_axes_locatable(ax1)
    cax1 = divider1.append_axes("right", size=colorbar_ax_percent, pad=0.05)
    plt.colorbar(im1, cax=cax1)
    #im1.set_clim(lower_bound, upper_bound)
    
    ax2.cla()
    im2 = ax2.imshow(zeta_2[l_1,l_2,l_3,:,b_2,:].real, origin='lower')
    ax2.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
    ax2.set_title('$b_2$ = ' + str(b_2), fontsize=sub_title_fontsize)
    ax2.set_xticks(range(nbins))
    ax2.set_yticks(range(nbins))
    ax2.set_xlabel("$b_1$",fontsize=xylabel_fontsize)
    ax2.set_ylabel("$b_3$", fontsize=xylabel_fontsize)
    divider2 = axgrid.make_axes_locatable(ax2)
    cax2 = divider2.append_axes("right", size=colorbar_ax_percent, pad=0.05)
    plt.colorbar(im2, cax=cax2)
    im2.set_clim(81*lower_bound, 81*upper_bound)
    
#     plt.cla()
#     plt.imshow(zeta_2[l_1,l_2,l_3,:,b_2,:].real, origin='lower')
#     plt.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
#     plt.title('$b_2$ = ' + str(b_2), fontsize=sub_title_fontsize)
#     plt.xticks(range(nbins))
#     plt.yticks(range(nbins))
#     plt.xlabel("$b_1$",fontsize=xylabel_fontsize)
#     plt.ylabel("$b_3$", fontsize=xylabel_fontsize)
#     plt.colorbar()
    
    ax3.cla()
    im3 = ax3.imshow(ratio[l_1,l_2,l_3,:,b_2,:].real/81, origin='lower')
    ax3.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
    ax3.set_title('$b_2$ = ' + str(b_2) + ', Ratio of $\\zeta$', fontsize=sub_title_fontsize)
    ax3.set_xticks(range(nbins))
    ax3.set_yticks(range(nbins))
    ax3.set_xlabel("$b_1$",fontsize=xylabel_fontsize)
    ax3.set_ylabel("$b_3$", fontsize=xylabel_fontsize)
    divider3 = axgrid.make_axes_locatable(ax3)
    cax3 = divider3.append_axes("right", size=colorbar_ax_percent, pad=0.05)
    plt.colorbar(im3, cax=cax3)
    im3.set_clim(-1, 1)
    
    #f.tight_layout()



out = widgets.interactive_output(make_plot, {'l_1':slider1,
                                     'l_2':slider2, 'l_3':slider3, 'b_1':slider4,
                                            'b_2':slider5, 'b_3':slider6,})

# we can add vertical and horizontal boxes for styling!
box1 = widgets.VBox([slider1])
ui1 = widgets.HBox([box1])

box2 = widgets.VBox([slider2,slider5])
ui2 = widgets.HBox([box2])

box3 = widgets.VBox([slider3])
ui3 = widgets.HBox([box3])

ui = widgets.HBox([ui1, ui2, ui3])



display(ui,out)
# Out:
# ...
# Output()

# %%
"""If you prefer %matplotlib notebook settings, use this version. They do the same thing.
(just remember to switch to the notebook setting in the first cell)"""

# ell_max=5
# nbins = np.shape(zeta)[-1]

# slider1 = widgets.IntSlider(
#                             value=0,
#                             min=0,
#                             max=ell_max,
#                             step=1,
#                             description=r'\(\ell_1\)')

# slider2 = widgets.IntSlider(
#                             value=0,
#                             min=0,
#                             max=ell_max,
#                             step=1,
#                             description=r'\(\ell_2\)')

# slider3 = widgets.IntSlider(
#                             value=0,
#                             min=0,
#                             max=ell_max,
#                             step=1,
#                             description=r'\(\ell_3\)')

# slider4 = widgets.IntSlider(
#                             value=0,
#                             min=0,
#                             max=nbins-1,
#                             step=1,
#                             description=r'\(b_1\)')

# slider5 = widgets.IntSlider(
#                             value=0,
#                             min=0,
#                             max=nbins-1,
#                             step=1,
#                             description=r'\(b_2\)')

# slider6 = widgets.IntSlider(
#                             value=0,
#                             min=0,
#                             max=nbins-1,
#                             step=1,
#                             description=r'\(b_3\)')


# def make_plot(l_1=0, l_2=0, l_3=0, b_1=0, b_2=0, b_3=0):
    
#     xylabel_fontsize = 22
#     sub_title_fontsize = 22
#     sup_title_fontsize = 30
#     text_fontsize = 18
    
#     ax1.cla()
#     ax1.imshow(zeta[l_1,l_2,l_3,b_1,:,:].real, origin='lower')
#     ax1.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
#     ax1.set_title('$b_1$ = ' + str(b_1), fontsize=sub_title_fontsize)
#     ax1.set_xticks(range(nbins))
#     ax1.set_yticks(range(nbins))
#     ax1.set_xlabel("$b_2$",fontsize=xylabel_fontsize)
#     ax1.set_ylabel("$b_3$", fontsize=xylabel_fontsize)
    
#     ax2.cla()
#     ax2.imshow(zeta[l_1,l_2,l_3,:,b_2,:].real, origin='lower')
#     ax2.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
#     ax2.set_title('$b_2$ = ' + str(b_2), fontsize=sub_title_fontsize)
#     ax2.set_xticks(range(nbins))
#     ax2.set_yticks(range(nbins))
#     ax2.set_xlabel("$b_1$",fontsize=xylabel_fontsize)
#     ax2.set_ylabel("$b_3$", fontsize=xylabel_fontsize)
    
#     ax3.cla()
#     ax3.imshow(zeta[l_1,l_2,l_3,:,:,b_3].real, origin='lower')
#     ax3.text(0,nbins-1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=text_fontsize)
#     ax3.set_title('$b_3$ = ' + str(b_3), fontsize=sub_title_fontsize)
#     ax3.set_xticks(range(nbins))
#     ax3.set_yticks(range(nbins))
#     ax3.set_xlabel("$b_1$",fontsize=xylabel_fontsize)
#     ax3.set_ylabel("$b_2$", fontsize=xylabel_fontsize)



# out = widgets.interactive_output(make_plot, {'l_1':slider1,
#                                      'l_2':slider2, 'l_3':slider3, 'b_1':slider4,
#                                             'b_2':slider5, 'b_3':slider6,})



# f, ((ax1,ax2,ax3)) = plt.subplots(1,3, figsize=(11,4))
# f.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$', fontsize=22)



# # we can add vertical and horizontal boxes for styling!
# box1 = widgets.VBox([slider1])
# ui1 = widgets.HBox([box1])

# box2 = widgets.VBox([slider2])
# ui2 = widgets.HBox([box2])

# box3 = widgets.VBox([slider3])
# ui3 = widgets.HBox([box3])

# box4 = widgets.VBox([slider4])
# ui4 = widgets.HBox([box4])

# box5 = widgets.VBox([slider5])
# ui5 = widgets.HBox([box5])

# box6 = widgets.VBox([slider6])
# ui6 = widgets.HBox([box6])

# display(ui1, out)
# display(ui2, out)
# display(ui3, out)
# print("This slider is for left plot")
# display(ui4, out)
# print("This slider is for middle plot")
# display(ui5, out)
# print("This slider is for right plot")
# display(ui6, out)
# make_plot()

# %% [markdown]
# # One can visualize all the plots side by side with the following cells

# %%
# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_3 = 0$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[:,:,0,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_2$", fontsize=20)
#                 plt.title("$b_1$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()

# print("\n\n\n")

# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_3 = 1$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[:,:,1,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_2$", fontsize=20)
#                 plt.title("$b_1$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()   

# print("\n\n\n")

# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_3 = 2$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[:,:,2,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_2$", fontsize=20)
#                 plt.title("$b_1$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()  

# print("\n\n\n")

# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_3 = 3$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[:,:,3,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_2$", fontsize=20)
#                 plt.title("$b_1$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()

# %%
# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_2 = 0$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[:,0,:,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_3$", fontsize=20)
#                 plt.title("$b_1$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()

# print("\n\n\n")

# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_2 = 1$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[:,1,:,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_3$", fontsize=20)
#                 plt.title("$b_1$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()   

# print("\n\n\n")

# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_2 = 2$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[:,2,:,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_3$", fontsize=20)
#                 plt.title("$b_1$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()  

# print("\n\n\n")

# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_2 = 3$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[:,3,:,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_3$", fontsize=20)
#                 plt.title("$b_1$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()

# %%
# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_1 = 0$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[0,:,:,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_3$", fontsize=20)
#                 plt.title("$b_2$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()

# print("\n\n\n")

# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_1 = 1$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[1,:,:,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_3$", fontsize=20)
#                 plt.title("$b_2$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()   

# print("\n\n\n")

# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_1 = 2$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[2,:,:,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_3$", fontsize=20)
#                 plt.title("$b_2$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()  

# print("\n\n\n")

# plt.figure(figsize=(15, 70))
# plt.suptitle('4PCF coefficients $\\zeta^{b_1 b_2 b_3}_{\ell_1 \ell_2 \ell_3}$ for $b_1 = 3$', fontsize='large')

# i = 0
# for l_1 in range(0,ell_max+1, 1):
#     for l_2 in range(0,ell_max+1, 1):
#         for l_3 in range(np.abs(l_1 - l_2), min(l_1 + l_2, ell_max)+1): 
#             plt.subplot(23, 5, (i)+1) 
#             plt.text(0,nbins - 1, index_dict[str(l_1) + str(l_2) + str(l_3)], c='white', fontsize=18)
#             plt.imshow(zeta[3,:,:,l_1,l_2,l_3].real, origin='lower')
#             plt.xticks(range(nbins))
#             plt.yticks(range(nbins))
#             if i == 0:
#                 plt.ylabel("$b_3$", fontsize=20)
#                 plt.title("$b_2$", fontsize = 20)
#             i+=1
            

# plt.tight_layout(rect=[0, 0.03, 1, 0.98])
# plt.show()
